# %%
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt

# %%
df = yf.download("TSLA")
# Out:
# /var/folders/lf/4_x8tqr94svf0jwj_by9x6w80000gn/T/ipykernel_22470/2739912864.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download("TSLA")
# [*********************100%***********************]  1 of 1 completed

# %%
returns = np.log(1 + df['Close', 'TSLA'].pct_change())
